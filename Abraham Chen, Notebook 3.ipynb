# %% [markdown]
# Submitted by: <br>
# Name: Abraham Chen <br>
# ID Number: 12205974 <br>
# Course: BS Mathematics with Specialization in Business Applications

# %% [markdown]
# # Zomato Exercise

# %% [markdown]
# Zomato is a restaurant aggregator website. The platform provides information, menus and user-reviews of restaurants as well as food delivery options from partner restaurants in select cities. You have been provided 3 datasets:
#
# - zomato.csv contains restaurant information like average_cost_for_two, cuisines
# - location.csv contains location of the restaurants like address, city, locality & etc
# - ratings.csv contains aggregate rating for each restaurant
#
# The different files are connected using the `id` columns which can be found in the different files. The id column is a unique identifier to represent a restaurant. You can use this to **merge** the different files.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Merge the zomato, location & ratings file into a signle dataframe and store it to the `merged_df` variable **(3pts)**

# %% [markdown]
# Create a DataFrame with zomato.csv:

# %%
zomato_df = pd.read_csv("zomato.csv")
zomato_df
# Out:
#             id  average_cost_for_two book_url  \
# 0      6316125                  1000      NaN
# 1     18409457                  1300      NaN
# 2      6307689                  1600      NaN
# 3     18581637                  1000      NaN
# 4      6315438                  3000      NaN
# ...        ...                   ...      ...
# 6825  18635649                  1000      NaN
# 6826   6318581                   400      NaN
# 6827   6318578                   450      NaN
# 6828   6309612                  1000      NaN
# 6829   6318582                   600      NaN
#
#                                         cuisines currency  \
# 0                                Japanese, Ramen        P
# 1                      Korean, Grill, Korean BBQ        P
# 2                             American, Filipino        P
# 3                                         Korean        P
# 4     Seafood, American, Mediterranean, Japanese        P
# ...

# %% [markdown]
# Create a DataFrame with ratings.csv:

# %%
ratings_df = pd.read_csv("ratings.csv")
ratings_df
# Out:
#             id  aggregate_rating rating_color rating_text  votes
# 0      6316125               4.9       3F7E00   Excellent   1394
# 1     18409457               4.6       3F7E00   Excellent    602
# 2      6307689               4.0       5BA829   Very Good    563
# 3     18581637               4.0       5BA829   Very Good    413
# 4      6315438               4.6       3F7E00   Excellent    960
# ...        ...               ...          ...         ...    ...
# 6825  18635649               2.9       FFBA00     Average      6
# 6826   6318581               3.0       CDD614     Average      5
# 6827   6318578               0.0       CBCBC8   Not rated      1
# 6828   6309612               3.7       9ACD32        Good     96
# 6829   6318582               0.0       CBCBC8   Not rated      2
#
# [6830 rows x 5 columns]

# %% [markdown]
# Create a DataFrame with location.csv:

# %%
location_df = pd.read_csv("location.csv")
location_df
# Out:
#             id                                            address  \
# 0      6316125  V. Corporate Center, Soliman Street, Salcedo V...
# 1     18409457  Level 3, Greenbelt 3, Ayala Center, Greenbelt,...
# 2      6307689  5012 P. Burgos Street, Poblacion, Makati City ...
# 3     18581637  CKB Centre, Tomas Morato Avenue Corner Scout R...
# 4      6315438  Sixth Floor, SM Aura Premier, C5 Road Corner 2...
# ...        ...                                                ...
# 6825  18635649   Westgate Center, Filinvest City, Muntinlupa City
# 6826   6318581  Zabarte Town Center, Zabarte Corner Camarin Ro...
# 6827   6318578  Zabarte Town Center, Zabarte Corner Camarin Ro...
# 6828   6309612  Greenhills Town Center, Granada Street, Valenc...
# 6829   6318582  Ground Floor, Zabarte Town Center, Zabarte Cor...
#
#                  city  city_id  country_id   latitude  \
# 0         Makati City       63         162  14.560313
# 1         Makati City       63         162  14.552137
# ...

# %% [markdown]
# Merge the three DataFrames together:

# %%
merged_df = zomato_df.merge(location_df, on="id").merge(ratings_df, on="id")
merged_df
# Out:
#             id  average_cost_for_two book_url  \
# 0      6316125                  1000      NaN
# 1     18409457                  1300      NaN
# 2      6307689                  1600      NaN
# 3     18581637                  1000      NaN
# 4      6315438                  3000      NaN
# ...        ...                   ...      ...
# 6825  18635649                  1000      NaN
# 6826   6318581                   400      NaN
# 6827   6318578                   450      NaN
# 6828   6309612                  1000      NaN
# 6829   6318582                   600      NaN
#
#                                         cuisines currency  \
# 0                                Japanese, Ramen        P
# 1                      Korean, Grill, Korean BBQ        P
# 2                             American, Filipino        P
# 3                                         Korean        P
# 4     Seafood, American, Mediterranean, Japanese        P
# ...

# %%
assert (6830, 35)==merged_df.shape

cols = ['id', 'address', 'city', 'city_id', 'country_id', 'latitude',
       'locality', 'locality_verbose', 'longitude', 'zipcode',
       'aggregate_rating', 'rating_color', 'rating_text', 'votes',
       'average_cost_for_two', 'book_url', 'cuisines', 'currency', 'deeplink',
       'events_url', 'featured_image', 'has_online_delivery',
       'has_table_booking', 'include_bogo_offers', 'is_book_form_web_view',
       'is_delivering_now', 'is_table_reservation_supported',
       'is_zomato_book_res', 'menu_url', 'mezzo_provider', 'name',
       'photos_url', 'price_range', 'thumb', 'url']

assert sorted(merged_df.columns) == sorted(cols)

# %% [markdown]
# 2. Create a function that returns the average aggregate rating for each city. Expected returned value is a Series datatype which contains name of city as index and average aggregate rating as value. **(2pts)**

# %%
def exercise_2(merged_df):
    return merged_df.groupby("city")["aggregate_rating"].agg("mean")

# %%
merged_df.groupby("city")["aggregate_rating"].agg("mean")
# Out:
# city
# Caloocan City       1.953509
# Las Piñas City      2.855738
# Makati City         3.250512
# Malabon City        1.558333
# Mandaluyong City    2.951919
# Manila              2.842652
# Marikina City       2.672512
# Muntinlupa City     2.962682
# Parañaque City      3.130100
# Pasay City          3.302075
# Pasig City          2.916086
# Pateros City        1.740000
# Quezon City         2.887946
# San Juan City       3.098462
# Tagaytay City       2.959259
# Taguig City         3.234105
# Valenzuela City     1.890741
# Name: aggregate_rating, dtype: float64

# %%
res_series = exercise_2(merged_df)
assert True == np.isclose(3.302075, res_series[res_series.index == 'Pasay City'],
                          rtol=1e-05, atol=1e-08, equal_nan=False)[0]
assert True == np.isclose(1.890741, res_series[res_series.index == 'Valenzuela City'],
                          rtol=1e-05, atol=1e-08, equal_nan=False)[0]
assert True == np.isclose(1.558333, res_series[res_series.index == 'Malabon City'],
                          rtol=1e-05, atol=1e-08, equal_nan=False)[0]

# %% [markdown]
# 3. Using the apply function of pandas convert the rating_text to a numeric equivalent. You are to introduce a new column in merged_df called `rating_numeric` which is based on the value from rating_text: **(3pts)**
#
# Excellent = 5 <br>
# Very Good = 4 <br>
# Good = 3 <br>
# Average = 2 <br>
# Poor = 1 <br>
# Not rated = 0 <br>

# %%
rating_dict = {"Excellent":5, "Very Good":4, "Good":3, "Average":2, "Poor":1, "Not rated":0}
merged_df["rating_numeric"] = merged_df["rating_text"].apply(lambda x: rating_dict.get(x))
merged_df[["name", "rating_numeric", "rating_text"]]
# Out:
#                            name  rating_numeric rating_text
# 0             Mendokoro Ramenba               5   Excellent
# 1            Soban K-Town Grill               5   Excellent
# 2               Filling Station               4   Very Good
# 3                Romantic Baboy               4   Very Good
# 4                NIU by Vikings               5   Excellent
# ...                         ...             ...         ...
# 6825              Trader Juan's               2     Average
# 6826                   Jollibee               2     Average
# 6827                 Goldilocks               0   Not rated
# 6828  Red Buffalo Wings & Pizza               3        Good
# 6829                  Greenwich               0   Not rated
#
# [6830 rows x 3 columns]

# %%
assert 868 == merged_df[merged_df.rating_numeric == 0].shape[0]
assert True == ('rating_numeric' in merged_df.columns)

# %% [markdown]
# 4. Create a function which filters the merged dataframe to only contain rows coming in from a specific city. Expected returned value is a dataframe **(2pts)**

# %%
merged_df
def exercise_4(merged_df, city):
    return merged_df[merged_df["city"] == city]

# %%
assert 'Makati City' == exercise_4(merged_df, 'Makati City').city.unique()[0]
assert (976, 36) == exercise_4(merged_df, 'Makati City').shape

assert 'Mandaluyong City' == exercise_4(merged_df, 'Mandaluyong City').city.unique()[0]
assert (443, 36) == exercise_4(merged_df, 'Mandaluyong City').shape

assert (0, 36) == exercise_4(merged_df, 'Quezon  City').shape

# %% [markdown]
# 5. Create a function to filter the dataframe to only contain certain columns passed in the function. Expected returned value is a dataframe **(1pt)**

# %%
merged_df
def exercise_5(merged_df, cols_to_filter):
    return merged_df[cols_to_filter]

# %%
cols = ['name', 'cuisines', 'city', 'aggregate_rating']
assert sorted(cols) == sorted(exercise_5(merged_df, cols).columns)
assert (6830, 4) == exercise_5(merged_df, cols).shape

cols = ['average_cost_for_two', 'book_url', 'cuisines', 'currency', 'deeplink',
       'events_url', 'featured_image', 'has_online_delivery',
       'has_table_booking', 'include_bogo_offers', 'is_book_form_web_view']
assert sorted(cols) == sorted(exercise_5(merged_df, cols).columns)
assert (6830, 11) == exercise_5(merged_df, cols).shape

# %% [markdown]
# 6.  What is the most common restaurant name in the dataset? **(2pts)** Write down your answer and show code used to come up with the answer.

# %%
merged_df.value_counts("name")
# Out:
# name
# Starbucks                         99
# Jollibee                          77
# McDonald's                        66
# KFC                               54
# BonChon Chicken                   49
#                                   ..
# HotBox Kitchen                     1
# Hotel Bar                          1
# Hotties Gourmet                    1
# House Manila - Remington Hotel     1
# ¡VENGO!                            1
# Name: count, Length: 3286, dtype: int64

# %% [markdown]
# The most common restaurant name is Starbucks, with 99 occurrences.

# %% [markdown]
# 7. Which restaurant has the most expensive average cost for two? **(2pts)** Write down your answer and show code used to come up with the answer.

# %%
merged_df[["name","average_cost_for_two"]].sort_values(by="average_cost_for_two", ascending=False)
# Out:
#                                            name  average_cost_for_two
# 1713                           The Tasting Room                 10000
# 5      Spiral - Sofitel Philippine Plaza Manila                  6000
# 1728               Medley Buffet - Okada Manila                  5400
# 1750  Wolfgang's Steakhouse by Wolfgang Zwiener                  5100
# 2039  Wolfgang's Steakhouse by Wolfgang Zwiener                  5100
# ...                                         ...                   ...
# 6796                           Katherine's Cafe                     0
# 4714                            The Baking Crew                     0
# 6482                                   Toritake                     0
# 6192                                  Sari Salo                     0
# 6509                                   KapeTayo                     0
#
# [6830 rows x 2 columns]

# %% [markdown]
# The restaurant with the most expensive average cost for two is The Tasting Room at 10,000 pesos.

# %% [markdown]
# 8. How many restaurants do not have a zipcode? **(1pt)** Write down your answer and show code used to come up with the answer.

# %%
merged_df[merged_df["zipcode"].isna()]
# Out:
#             id  average_cost_for_two book_url  \
# 0      6316125                  1000      NaN
# 1     18409457                  1300      NaN
# 3     18581637                  1000      NaN
# 4      6315438                  3000      NaN
# 5      6300010                  6000      NaN
# ...        ...                   ...      ...
# 6825  18635649                  1000      NaN
# 6826   6318581                   400      NaN
# 6827   6318578                   450      NaN
# 6828   6309612                  1000      NaN
# 6829   6318582                   600      NaN
#
#                                         cuisines currency  \
# 0                                Japanese, Ramen        P
# 1                      Korean, Grill, Korean BBQ        P
# 3                                         Korean        P
# 4     Seafood, American, Mediterranean, Japanese        P
# 5                        European, Asian, Indian        P
# ...

# %% [markdown]
# There are 6713 restaurants without a zipcode.

# %% [markdown]
# 9. How many restaurants in the dataset allow online delivery? **(1pt)** Write down your answer and show code used to come up with the answer.

# %%
merged_df[merged_df["has_online_delivery"] == 1]
# Out:
# Empty DataFrame
# Columns: [id, average_cost_for_two, book_url, cuisines, currency, deeplink, events_url, featured_image, has_online_delivery, has_table_booking, include_bogo_offers, is_book_form_web_view, is_delivering_now, is_table_reservation_supported, is_zomato_book_res, menu_url, mezzo_provider, name, photos_url, price_range, thumb, url, address, city, city_id, country_id, latitude, locality, locality_verbose, longitude, zipcode, aggregate_rating, rating_color, rating_text, votes, rating_numeric]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# No restaurants support online delivery (sad!)

# %% [markdown]
# 10. Which locality has more expensive food? Poblacion or Salcedo Village? **(3pts)** Write down your answer and show code used to come up with the answer.

# %%
pobla_salcedo_filter = merged_df[(merged_df["locality"] == "Poblacion") | (merged_df["locality"] == "Salcedo Village")]
pobla_salcedo_filter.groupby("locality")["average_cost_for_two"].agg("mean")
# Out:
# locality
# Poblacion          898.214286
# Salcedo Village    989.102564
# Name: average_cost_for_two, dtype: float64

# %% [markdown]
# Salcedo Village has the more expensive food, where the aggregate average cost for two is 989.10 pesos.
